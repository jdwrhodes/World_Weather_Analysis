# %%
import pandas as pd
import numpy as np
from datetime import datetime
from citipy import citipy
import requests
from config import weather_api_key

# %%
lats = np.random.uniform(-90,90, size=2000)
lngs = np.random.uniform(-180,180, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 772

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):

    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    city_url = url + '&q=' + city.replace(' ', '+')
    
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
          
    record_count += 1  

    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather['weather'][0]['description']
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather_description})

    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yerbogachen
# Processing Record 2 of Set 1 | bronnoysund
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | kudahuvadhoo
# Processing Record 6 of Set 1 | esperance
# Processing Record 7 of Set 1 | airai
# Processing Record 8 of Set 1 | tasiilaq
# Processing Record 9 of Set 1 | quelimane
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | salalah
# Processing Record 12 of Set 1 | avera
# Processing Record 13 of Set 1 | kaeo
# Processing Record 14 of Set 1 | batagay-alyta
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | villa carlos paz
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | arraial do cabo
# Processing Record 19 of Set 1 | kolondieba
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | maningrida
# Processing Record 22 of Set 1 | oksfjord
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | rincon
# Processing Record 25 of Set 1 | chapais
# Processing Record 26 of Set 1 | ahuimanu
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | bathsheba
# Processing Record 29 of Set 1 | chikwawa
# Processing Record 30 of Set 1 | bengkulu
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | tuatapere
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | atuona
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 1 | sept-iles
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | arthur
# Processing Record 41 of Set 1 | stabat
# Processing Record 42 of Set 1 | biak
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | chokurdakh
# Processing Record 47 of Set 1 | ilulissat
# Processing Record 48 of Set 1 | mulege
# Processing Record 49 of Set 1 | awjilah
# Processing Record 50 of Set 1 | east london
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | lyss
# Processing Record 3 of Set 2 | mahebourg
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | teknaf
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | coihaique
# Processing Record 9 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 2 | depok
# Processing Record 12 of Set 2 | bambous virieux
# Processing Record 13 of Set 2 | mar del plata
# Processing Record 14 of Set 2 | sakakah
# Processing Record 15 of Set 2 | zhanaozen
# Processing Record 16 of Set 2 | ponta do sol
# Processing Record 17 of Set 2 | cabo san lucas
# Processing Record 18 of Set 2 | aden
# Processing Record 19 of Set 2 | villanueva
# Processing Record 20 of Set 2 | guerrero negro
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | saint-augustin
# Processing Record 23 of Set 2 | haines junction
# Processing Record 24 of Set 2 | yirol
# City not found. Skipping...
# Processing Record 25 of Set 2 | souillac
# Processing Record 26 of Set 2 | srednekolymsk
# Processing Record 27 of Set 2 | hilo
# Processing Record 28 of Set 2 | avarua
# Processing Record 29 of Set 2 | clarence town
# Processing Record 30 of Set 2 | cidreira
# Processing Record 31 of Set 2 | komsomolskiy
# Processing Record 32 of Set 2 | sur
# Processing Record 33 of Set 2 | poum
# Processing Record 34 of Set 2 | cherskiy
# Processing Record 35 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 2 | kruisfontein
# Processing Record 37 of Set 2 | el espino de santa rosa
# Processing Record 38 of Set 2 | lenger
# Processing Record 39 of Set 2 | kodiak
# Processing Record 40 of Set 2 | mayumba
# Processing Record 41 of Set 2 | butaritari
# Processing Record 42 of Set 2 | huntingdon
# Processing Record 43 of Set 2 | busselton
# Processing Record 44 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 2 | constitucion
# Processing Record 46 of Set 2 | maragogi
# Processing Record 47 of Set 2 | jacqueville
# Processing Record 48 of Set 2 | san juan
# Processing Record 49 of Set 2 | yellowknife
# Processing Record 50 of Set 2 | iqaluit
# Processing Record 1 of Set 3 | saldanha
# Processing Record 2 of Set 3 | faanui
# Processing Record 3 of Set 3 | san andres
# Processing Record 4 of Set 3 | geraldton
# Processing Record 5 of Set 3 | castro
# Processing Record 6 of Set 3 | tamandare
# Processing Record 7 of Set 3 | barrow
# Processing Record 8 of Set 3 | zhangjiakou
# Processing Record 9 of Set 3 | bethel
# Processing Record 10 of Set 3 | hellvik
# Processing Record 11 of Set 3 | lasa
# Processing Record 12 of Set 3 | gijon
# Processing Record 13 of Set 3 | florence
# Processing Record 14 of Set 3 | lazaro cardenas
# Processing Record 15 of Set 3 | ribeira grande
# Processing Record 16 of Set 3 | maniitsoq
# Processing Record 17 of Set 3 | upernavik
# Processing Record 18 of Set 3 | goderich
# Processing Record 19 of Set 3 | tarko-sale
# Processing Record 20 of Set 3 | palauig
# Processing Record 21 of Set 3 | meadow lake
# Processing Record 22 of Set 3 | talnakh
# Processing Record 23 of Set 3 | sheboygan
# Processing Record 24 of Set 3 | doha
# Processing Record 25 of Set 3 | yinchuan
# Processing Record 26 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 3 | tiksi
# Processing Record 28 of Set 3 | sitka
# Processing Record 29 of Set 3 | masunga
# Processing Record 30 of Set 3 | ostrovnoy
# Processing Record 31 of Set 3 | seoul
# Processing Record 32 of Set 3 | lagoa
# Processing Record 33 of Set 3 | odweyne
# Processing Record 34 of Set 3 | hasaki
# Processing Record 35 of Set 3 | saint-philippe
# Processing Record 36 of Set 3 | jacareacanga
# Processing Record 37 of Set 3 | inhambane
# Processing Record 38 of Set 3 | palmer
# Processing Record 39 of Set 3 | ohara
# Processing Record 40 of Set 3 | san patricio
# Processing Record 41 of Set 3 | ewa beach
# Processing Record 42 of Set 3 | port elizabeth
# Processing Record 43 of Set 3 | itacare
# Processing Record 44 of Set 3 | solnechnyy
# Processing Record 45 of Set 3 | kidal
# Processing Record 46 of Set 3 | muroto
# Processing Record 47 of Set 3 | mitchell
# Processing Record 48 of Set 3 | iranshahr
# Processing Record 49 of Set 3 | norman wells
# Processing Record 50 of Set 3 | tenenkou
# Processing Record 1 of Set 4 | muli
# Processing Record 2 of Set 4 | qaanaaq
# Processing Record 3 of Set 4 | minot
# Processing Record 4 of Set 4 | san cristobal
# Processing Record 5 of Set 4 | gogrial
# Processing Record 6 of Set 4 | chicama
# Processing Record 7 of Set 4 | san carlos de bariloche
# Processing Record 8 of Set 4 | umm ruwabah
# City not found. Skipping...
# Processing Record 9 of Set 4 | velikiy ustyug
# Processing Record 10 of Set 4 | kamyshin
# Processing Record 11 of Set 4 | bitung
# Processing Record 12 of Set 4 | minsk
# Processing Record 13 of Set 4 | bacolod
# Processing Record 14 of Set 4 | padang
# Processing Record 15 of Set 4 | nikolskoye
# Processing Record 16 of Set 4 | khatanga
# Processing Record 17 of Set 4 | hofn
# Processing Record 18 of Set 4 | mattawa
# Processing Record 19 of Set 4 | pandamatenga
# Processing Record 20 of Set 4 | touros
# Processing Record 21 of Set 4 | berezovyy
# Processing Record 22 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 4 | dingle
# Processing Record 24 of Set 4 | ngama
# Processing Record 25 of Set 4 | byron bay
# Processing Record 26 of Set 4 | ballina
# Processing Record 27 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 4 | thompson
# Processing Record 29 of Set 4 | coquimbo
# Processing Record 30 of Set 4 | andenes
# Processing Record 31 of Set 4 | kindu
# Processing Record 32 of Set 4 | ugoofaaru
# Processing Record 33 of Set 4 | sarkand
# Processing Record 34 of Set 4 | bambanglipuro
# Processing Record 35 of Set 4 | graaff-reinet
# Processing Record 36 of Set 4 | coahuayana
# Processing Record 37 of Set 4 | ambovombe
# Processing Record 38 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 4 | vardo
# Processing Record 41 of Set 4 | luena
# Processing Record 42 of Set 4 | christchurch
# Processing Record 43 of Set 4 | puerto baquerizo moreno
# Processing Record 44 of Set 4 | xuzhou
# Processing Record 45 of Set 4 | rolla
# Processing Record 46 of Set 4 | sfantu gheorghe
# Processing Record 47 of Set 4 | bubaque
# Processing Record 48 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 4 | verkhoyansk
# Processing Record 50 of Set 4 | san quintin
# Processing Record 1 of Set 5 | lebu
# Processing Record 2 of Set 5 | bandarbeyla
# Processing Record 3 of Set 5 | khvorostyanka
# Processing Record 4 of Set 5 | waipawa
# Processing Record 5 of Set 5 | cairns
# Processing Record 6 of Set 5 | nagapattinam
# Processing Record 7 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 5 | najran
# Processing Record 9 of Set 5 | kathmandu
# Processing Record 10 of Set 5 | boca do acre
# Processing Record 11 of Set 5 | narsaq
# Processing Record 12 of Set 5 | ahipara
# Processing Record 13 of Set 5 | mapastepec
# Processing Record 14 of Set 5 | newport
# Processing Record 15 of Set 5 | usoke
# Processing Record 16 of Set 5 | dunda
# Processing Record 17 of Set 5 | torbat-e jam
# Processing Record 18 of Set 5 | iracoubo
# Processing Record 19 of Set 5 | zhigansk
# Processing Record 20 of Set 5 | severo-kurilsk
# Processing Record 21 of Set 5 | chuy
# Processing Record 22 of Set 5 | alofi
# Processing Record 23 of Set 5 | katangli
# Processing Record 24 of Set 5 | mandalgovi
# Processing Record 25 of Set 5 | beringovskiy
# Processing Record 26 of Set 5 | saint george
# Processing Record 27 of Set 5 | swiecie
# Processing Record 28 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 5 | mehamn
# Processing Record 30 of Set 5 | porbandar
# Processing Record 31 of Set 5 | kattivakkam
# Processing Record 32 of Set 5 | hervey bay
# Processing Record 33 of Set 5 | reyes
# Processing Record 34 of Set 5 | harper
# Processing Record 35 of Set 5 | isangel
# Processing Record 36 of Set 5 | koumac
# Processing Record 37 of Set 5 | nanortalik
# Processing Record 38 of Set 5 | nishihara
# Processing Record 39 of Set 5 | gigmoto
# Processing Record 40 of Set 5 | lodja
# Processing Record 41 of Set 5 | basco
# Processing Record 42 of Set 5 | mazagao
# Processing Record 43 of Set 5 | klaksvik
# Processing Record 44 of Set 5 | skibbereen
# Processing Record 45 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 5 | mount gambier
# Processing Record 47 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 5 | kushima
# Processing Record 49 of Set 5 | moron
# Processing Record 50 of Set 5 | zhelnino
# City not found. Skipping...
# Processing Record 1 of Set 6 | pangnirtung
# Processing Record 2 of Set 6 | port keats
# Processing Record 3 of Set 6 | ayan
# Processing Record 4 of Set 6 | vila velha
# Processing Record 5 of Set 6 | te anau
# Processing Record 6 of Set 6 | pavlovka
# Processing Record 7 of Set 6 | luderitz
# Processing Record 8 of Set 6 | carutapera
# Processing Record 9 of Set 6 | chernenko
# Processing Record 10 of Set 6 | ronneby
# Processing Record 11 of Set 6 | salmon creek
# Processing Record 12 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 6 | udachnyy
# Processing Record 14 of Set 6 | whyalla
# Processing Record 15 of Set 6 | eyl
# Processing Record 16 of Set 6 | mayor pablo lagerenza
# Processing Record 17 of Set 6 | beitbridge
# Processing Record 18 of Set 6 | marawi
# Processing Record 19 of Set 6 | diapaga
# Processing Record 20 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 22 of Set 6 | eldorado
# Processing Record 23 of Set 6 | koungou
# Processing Record 24 of Set 6 | hirara
# Processing Record 25 of Set 6 | portland
# Processing Record 26 of Set 6 | lokoja
# Processing Record 27 of Set 6 | champerico
# Processing Record 28 of Set 6 | asau
# Processing Record 29 of Set 6 | clyde river
# Processing Record 30 of Set 6 | tuktoyaktuk
# Processing Record 31 of Set 6 | samarai
# Processing Record 32 of Set 6 | hima
# Processing Record 33 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 34 of Set 6 | tall kayf
# Processing Record 35 of Set 6 | pyaozerskiy
# Processing Record 36 of Set 6 | belousovka
# Processing Record 37 of Set 6 | maba
# Processing Record 38 of Set 6 | thinadhoo
# Processing Record 39 of Set 6 | kholodnyy
# Processing Record 40 of Set 6 | kostyantynivka
# Processing Record 41 of Set 6 | camacha
# Processing Record 42 of Set 6 | kieta
# Processing Record 43 of Set 6 | sao filipe
# Processing Record 44 of Set 6 | belyy yar
# Processing Record 45 of Set 6 | cali
# Processing Record 46 of Set 6 | puerto narino
# Processing Record 47 of Set 6 | melnikovo
# Processing Record 48 of Set 6 | jatibonico
# Processing Record 49 of Set 6 | kerman
# Processing Record 50 of Set 6 | bellmead
# Processing Record 1 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 7 | enshi
# Processing Record 3 of Set 7 | ormara
# Processing Record 4 of Set 7 | palu
# Processing Record 5 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 7 | saskylakh
# Processing Record 7 of Set 7 | shimoda
# Processing Record 8 of Set 7 | carnarvon
# Processing Record 9 of Set 7 | burica
# City not found. Skipping...
# Processing Record 10 of Set 7 | kavieng
# Processing Record 11 of Set 7 | kaitangata
# Processing Record 12 of Set 7 | pestovo
# Processing Record 13 of Set 7 | matay
# Processing Record 14 of Set 7 | havre-saint-pierre
# Processing Record 15 of Set 7 | turukhansk
# Processing Record 16 of Set 7 | charlottesville
# Processing Record 17 of Set 7 | swan hill
# Processing Record 18 of Set 7 | coruripe
# Processing Record 19 of Set 7 | wanlaweyn
# Processing Record 20 of Set 7 | port lincoln
# Processing Record 21 of Set 7 | tura
# Processing Record 22 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 7 | bonga
# Processing Record 24 of Set 7 | zavyalovo
# Processing Record 25 of Set 7 | vung tau
# Processing Record 26 of Set 7 | manzhouli
# Processing Record 27 of Set 7 | bam
# Processing Record 28 of Set 7 | port augusta
# Processing Record 29 of Set 7 | namibe
# Processing Record 30 of Set 7 | cabanbanan
# Processing Record 31 of Set 7 | borlange
# City not found. Skipping...
# Processing Record 32 of Set 7 | margate
# Processing Record 33 of Set 7 | panalingaan
# Processing Record 34 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 35 of Set 7 | clovis
# Processing Record 36 of Set 7 | munirabad
# Processing Record 37 of Set 7 | tautira
# Processing Record 38 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 39 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 7 | metu
# Processing Record 41 of Set 7 | quatre cocos
# Processing Record 42 of Set 7 | khairagarh
# Processing Record 43 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 7 | viedma
# Processing Record 45 of Set 7 | odry
# Processing Record 46 of Set 7 | jalu
# Processing Record 47 of Set 7 | diamantino
# Processing Record 48 of Set 7 | am timan
# Processing Record 49 of Set 7 | tsogni
# Processing Record 50 of Set 7 | port macquarie
# Processing Record 1 of Set 8 | katsuura
# Processing Record 2 of Set 8 | pisco
# Processing Record 3 of Set 8 | ngunguru
# Processing Record 4 of Set 8 | suclayin
# Processing Record 5 of Set 8 | aykhal
# Processing Record 6 of Set 8 | zheshart
# Processing Record 7 of Set 8 | porto novo
# Processing Record 8 of Set 8 | vao
# Processing Record 9 of Set 8 | rocha
# Processing Record 10 of Set 8 | victoria
# Processing Record 11 of Set 8 | codrington
# Processing Record 12 of Set 8 | longyearbyen
# Processing Record 13 of Set 8 | yar-sale
# Processing Record 14 of Set 8 | temiscaming
# Processing Record 15 of Set 8 | burgeo
# Processing Record 16 of Set 8 | provideniya
# Processing Record 17 of Set 8 | sagarejo
# Processing Record 18 of Set 8 | campos novos
# Processing Record 19 of Set 8 | sohag
# Processing Record 20 of Set 8 | tecoanapa
# Processing Record 21 of Set 8 | ekhabi
# Processing Record 22 of Set 8 | luanda
# Processing Record 23 of Set 8 | kankon
# Processing Record 24 of Set 8 | ixtapa
# Processing Record 25 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 26 of Set 8 | burewala
# Processing Record 27 of Set 8 | sungaipenuh
# Processing Record 28 of Set 8 | homer
# Processing Record 29 of Set 8 | opochka
# Processing Record 30 of Set 8 | teacapan
# Processing Record 31 of Set 8 | humaita
# Processing Record 32 of Set 8 | griffith
# Processing Record 33 of Set 8 | douentza
# Processing Record 34 of Set 8 | tessalit
# Processing Record 35 of Set 8 | kerema
# Processing Record 36 of Set 8 | kamaishi
# Processing Record 37 of Set 8 | zeya
# Processing Record 38 of Set 8 | grindavik
# Processing Record 39 of Set 8 | fallon
# Processing Record 40 of Set 8 | victoriaville
# Processing Record 41 of Set 8 | kenai
# Processing Record 42 of Set 8 | fortuna
# Processing Record 43 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 44 of Set 8 | mecca
# Processing Record 45 of Set 8 | husavik
# Processing Record 46 of Set 8 | kalispell
# Processing Record 47 of Set 8 | westport
# Processing Record 48 of Set 8 | poli
# Processing Record 49 of Set 8 | swellendam
# Processing Record 50 of Set 8 | nautla
# Processing Record 1 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 9 | saint-pierre
# Processing Record 3 of Set 9 | paita
# Processing Record 4 of Set 9 | biscarrosse
# Processing Record 5 of Set 9 | otradnoye
# Processing Record 6 of Set 9 | miranda
# Processing Record 7 of Set 9 | talas
# Processing Record 8 of Set 9 | waddan
# Processing Record 9 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 9 | hobyo
# Processing Record 11 of Set 9 | lorengau
# Processing Record 12 of Set 9 | chunskiy
# Processing Record 13 of Set 9 | gweru
# Processing Record 14 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 15 of Set 9 | qena
# Processing Record 16 of Set 9 | verkhnyaya inta
# Processing Record 17 of Set 9 | joensuu
# Processing Record 18 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 9 | glendive
# Processing Record 20 of Set 9 | sulangan
# Processing Record 21 of Set 9 | nuuk
# Processing Record 22 of Set 9 | smidovich
# Processing Record 23 of Set 9 | torbay
# Processing Record 24 of Set 9 | mandal
# Processing Record 25 of Set 9 | jucuaran
# Processing Record 26 of Set 9 | payakumbuh
# Processing Record 27 of Set 9 | jiangyou
# Processing Record 28 of Set 9 | nabire
# Processing Record 29 of Set 9 | sola
# Processing Record 30 of Set 9 | santa fe
# Processing Record 31 of Set 9 | amapa
# Processing Record 32 of Set 9 | tilichiki
# Processing Record 33 of Set 9 | correntina
# Processing Record 34 of Set 9 | vostok
# Processing Record 35 of Set 9 | westonaria
# Processing Record 36 of Set 9 | hami
# Processing Record 37 of Set 9 | ferrol
# Processing Record 38 of Set 9 | sosnovo-ozerskoye
# Processing Record 39 of Set 9 | show low
# Processing Record 40 of Set 9 | boa vista
# Processing Record 41 of Set 9 | flinders
# Processing Record 42 of Set 9 | tokur
# Processing Record 43 of Set 9 | upington
# Processing Record 44 of Set 9 | hanyang
# Processing Record 45 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 46 of Set 9 | krasnoarmeysk
# Processing Record 47 of Set 9 | baruun-urt
# Processing Record 48 of Set 9 | tadine
# Processing Record 49 of Set 9 | masvingo
# Processing Record 50 of Set 9 | quijingue
# Processing Record 1 of Set 10 | chumikan
# Processing Record 2 of Set 10 | lufilufi
# Processing Record 3 of Set 10 | santa cruz
# Processing Record 4 of Set 10 | chiredzi
# Processing Record 5 of Set 10 | muravlenko
# Processing Record 6 of Set 10 | sistranda
# Processing Record 7 of Set 10 | bilma
# Processing Record 8 of Set 10 | beberibe
# Processing Record 9 of Set 10 | moose factory
# Processing Record 10 of Set 10 | dengzhou
# Processing Record 11 of Set 10 | cayenne
# Processing Record 12 of Set 10 | binzhou
# Processing Record 13 of Set 10 | puerto ayacucho
# Processing Record 14 of Set 10 | bonthe
# Processing Record 15 of Set 10 | tottori
# Processing Record 16 of Set 10 | naze
# Processing Record 17 of Set 10 | denpasar
# Processing Record 18 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 19 of Set 10 | wuwei
# Processing Record 20 of Set 10 | okha
# Processing Record 21 of Set 10 | oranjemund
# Processing Record 22 of Set 10 | mol
# Processing Record 23 of Set 10 | san rafael
# Processing Record 24 of Set 10 | sungairaya
# Processing Record 25 of Set 10 | abha
# Processing Record 26 of Set 10 | opuwo
# Processing Record 27 of Set 10 | lata
# Processing Record 28 of Set 10 | vokhtoga
# Processing Record 29 of Set 10 | sheregesh
# Processing Record 30 of Set 10 | isabela
# Processing Record 31 of Set 10 | rawson
# Processing Record 32 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 10 | hualmay
# Processing Record 34 of Set 10 | khandyga
# Processing Record 35 of Set 10 | zhezkazgan
# Processing Record 36 of Set 10 | gallup
# Processing Record 37 of Set 10 | shimanovsk
# Processing Record 38 of Set 10 | la ronge
# Processing Record 39 of Set 10 | araouane
# Processing Record 40 of Set 10 | yeniseysk
# Processing Record 41 of Set 10 | kristiinankaupunki
# Processing Record 42 of Set 10 | nizhniy tagil
# Processing Record 43 of Set 10 | gabu
# Processing Record 44 of Set 10 | batemans bay
# Processing Record 45 of Set 10 | mitu
# Processing Record 46 of Set 10 | magdagachi
# Processing Record 47 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 10 | benguela
# Processing Record 49 of Set 10 | pauini
# Processing Record 50 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 11 | talikota
# Processing Record 2 of Set 11 | paucartambo
# City not found. Skipping...
# Processing Record 3 of Set 11 | yuli
# Processing Record 4 of Set 11 | novoilinsk
# Processing Record 5 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 6 of Set 11 | glens falls
# Processing Record 7 of Set 11 | hakodate
# Processing Record 8 of Set 11 | turayf
# Processing Record 9 of Set 11 | livingston
# Processing Record 10 of Set 11 | sile
# Processing Record 11 of Set 11 | chaplynka
# Processing Record 12 of Set 11 | galveston
# Processing Record 13 of Set 11 | whitianga
# Processing Record 14 of Set 11 | hambantota
# Processing Record 15 of Set 11 | alice springs
# Processing Record 16 of Set 11 | mattru
# Processing Record 17 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 18 of Set 11 | ojinaga
# Processing Record 19 of Set 11 | mackenzie
# Processing Record 20 of Set 11 | dzhebariki-khaya
# Processing Record 21 of Set 11 | laredo
# Processing Record 22 of Set 11 | tooele
# Processing Record 23 of Set 11 | naples
# Processing Record 24 of Set 11 | gimli
# Processing Record 25 of Set 11 | faya
# Processing Record 26 of Set 11 | taoudenni
# Processing Record 27 of Set 11 | svetlogorsk
# Processing Record 28 of Set 11 | turje
# Processing Record 29 of Set 11 | san rafael del sur
# Processing Record 30 of Set 11 | mezhdurechenskiy
# Processing Record 31 of Set 11 | manyana
# Processing Record 32 of Set 11 | wucheng
# Processing Record 33 of Set 11 | lermontovka
# Processing Record 34 of Set 11 | port blair
# Processing Record 35 of Set 11 | calbuco
# Processing Record 36 of Set 11 | jumla
# Processing Record 37 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 38 of Set 11 | itarema
# Processing Record 39 of Set 11 | penzance
# Processing Record 40 of Set 11 | karoi
# Processing Record 41 of Set 11 | necochea
# Processing Record 42 of Set 11 | ruza
# Processing Record 43 of Set 11 | oriximina
# Processing Record 44 of Set 11 | kankaanpaa
# Processing Record 45 of Set 11 | nome
# Processing Record 46 of Set 11 | okhotsk
# Processing Record 47 of Set 11 | atambua
# Processing Record 48 of Set 11 | miri
# Processing Record 49 of Set 11 | borogontsy
# Processing Record 50 of Set 11 | bolonchen
# City not found. Skipping...
# Processing Record 1 of Set 12 | comillas
# Processing Record 2 of Set 12 | srivardhan
# Processing Record 3 of Set 12 | dali
# Processing Record 4 of Set 12 | cap malheureux
# Processing Record 5 of Set 12 | vestmannaeyjar
# Processing Record 6 of Set 12 | guicheng
# City not found. Skipping...
# Processing Record 7 of Set 12 | kachiry
# Processing Record 8 of Set 12 | falmouth
# Processing Record 9 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 12 | beira
# Processing Record 11 of Set 12 | grand gaube
# Processing Record 12 of Set 12 | wyndham
# Processing Record 13 of Set 12 | arman
# Processing Record 14 of Set 12 | ancud
# Processing Record 15 of Set 12 | churumuco
# City not found. Skipping...
# Processing Record 16 of Set 12 | porto walter
# Processing Record 17 of Set 12 | curitiba
# Processing Record 18 of Set 12 | birjand
# Processing Record 19 of Set 12 | rosarito
# Processing Record 20 of Set 12 | buala
# Processing Record 21 of Set 12 | mbandaka
# Processing Record 22 of Set 12 | dalby
# Processing Record 23 of Set 12 | duobao
# Processing Record 24 of Set 12 | shwebo
# Processing Record 25 of Set 12 | mazulskiy
# City not found. Skipping...
# Processing Record 26 of Set 12 | deputatskiy
# Processing Record 27 of Set 12 | sangar
# Processing Record 28 of Set 12 | mongu
# Processing Record 29 of Set 12 | preobrazheniye
# Processing Record 30 of Set 12 | hamilton
# Processing Record 31 of Set 12 | vidalia
# Processing Record 32 of Set 12 | sorong
# Processing Record 33 of Set 12 | sigli
# Processing Record 34 of Set 12 | finsterwalde
# Processing Record 35 of Set 12 | skalnyy
# City not found. Skipping...
# Processing Record 36 of Set 12 | comodoro rivadavia
# Processing Record 37 of Set 12 | yulara
# Processing Record 38 of Set 12 | waingapu
# Processing Record 39 of Set 12 | ghatsila
# Processing Record 40 of Set 12 | port shepstone
# Processing Record 41 of Set 12 | kodinsk
# Processing Record 42 of Set 12 | adrar
# Processing Record 43 of Set 12 | kurumkan
# Processing Record 44 of Set 12 | nizhniy tsasuchey
# Processing Record 45 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 46 of Set 12 | kavaratti
# Processing Record 47 of Set 12 | kemise
# Processing Record 48 of Set 12 | belmonte
# Processing Record 49 of Set 12 | vanimo
# Processing Record 50 of Set 12 | bumba
# Processing Record 1 of Set 13 | inirida
# Processing Record 2 of Set 13 | erhlin
# City not found. Skipping...
# Processing Record 3 of Set 13 | kondinskoye
# Processing Record 4 of Set 13 | sakaiminato
# Processing Record 5 of Set 13 | chabahar
# Processing Record 6 of Set 13 | atbasar
# Processing Record 7 of Set 13 | marzuq
# Processing Record 8 of Set 13 | ajdabiya
# Processing Record 9 of Set 13 | paamiut
# Processing Record 10 of Set 13 | aksarka
# Processing Record 11 of Set 13 | imbituba
# Processing Record 12 of Set 13 | thunder bay
# Processing Record 13 of Set 13 | yeppoon
# Processing Record 14 of Set 13 | chapeco
# Processing Record 15 of Set 13 | leningradskiy
# Processing Record 16 of Set 13 | kirakira
# Processing Record 17 of Set 13 | zonalnoye
# City not found. Skipping...
# Processing Record 18 of Set 13 | caravelas
# Processing Record 19 of Set 13 | forio
# Processing Record 20 of Set 13 | sibolga
# Processing Record 21 of Set 13 | huilong
# Processing Record 22 of Set 13 | aksha
# Processing Record 23 of Set 13 | labuhan
# Processing Record 24 of Set 13 | kloulklubed
# Processing Record 25 of Set 13 | ucluelet
# Processing Record 26 of Set 13 | mareeba
# Processing Record 27 of Set 13 | havoysund
# Processing Record 28 of Set 13 | nanakuli
# Processing Record 29 of Set 13 | makakilo city
# Processing Record 30 of Set 13 | manbij
# Processing Record 31 of Set 13 | roald
# Processing Record 32 of Set 13 | vsevolodo-vilva
# City not found. Skipping...
# Processing Record 33 of Set 13 | ainazi
# Processing Record 34 of Set 13 | dien bien
# City not found. Skipping...
# Processing Record 35 of Set 13 | saint-joseph
# Processing Record 36 of Set 13 | acapulco
# Processing Record 37 of Set 13 | never
# Processing Record 38 of Set 13 | kosh-agach
# Processing Record 39 of Set 13 | surt
# Processing Record 40 of Set 13 | furano
# Processing Record 41 of Set 13 | pevek
# Processing Record 42 of Set 13 | mahaicony
# City not found. Skipping...
# Processing Record 43 of Set 13 | eskil
# Processing Record 44 of Set 13 | along
# Processing Record 45 of Set 13 | liangxiang
# Processing Record 46 of Set 13 | sinnamary
# Processing Record 47 of Set 13 | banmo
# City not found. Skipping...
# Processing Record 48 of Set 13 | ulaangom
# Processing Record 49 of Set 13 | pitiquito
# Processing Record 50 of Set 13 | vila franca do campo
# Processing Record 1 of Set 14 | fukuma
# Processing Record 2 of Set 14 | broome
# Processing Record 3 of Set 14 | mezhdurechensk
# Processing Record 4 of Set 14 | chateaubelair
# Processing Record 5 of Set 14 | botad
# Processing Record 6 of Set 14 | san ramon
# Processing Record 7 of Set 14 | mangaratiba
# Processing Record 8 of Set 14 | gdov
# Processing Record 9 of Set 14 | hovd
# Processing Record 10 of Set 14 | kampong thum
# Processing Record 11 of Set 14 | maceio
# Processing Record 12 of Set 14 | lakes entrance
# Processing Record 13 of Set 14 | korla
# Processing Record 14 of Set 14 | sergeyevka
# Processing Record 15 of Set 14 | llanes
# Processing Record 16 of Set 14 | kuryk
# Processing Record 17 of Set 14 | mucuri
# Processing Record 18 of Set 14 | puerto escondido
# Processing Record 19 of Set 14 | paka
# Processing Record 20 of Set 14 | dunedin
# Processing Record 21 of Set 14 | lambarene
# Processing Record 22 of Set 14 | corbelia
# Processing Record 23 of Set 14 | kampene
# Processing Record 24 of Set 14 | gusau
# Processing Record 25 of Set 14 | tiznit
# Processing Record 26 of Set 14 | road town
# Processing Record 27 of Set 14 | artyshta
# Processing Record 28 of Set 14 | charlestown
# Processing Record 29 of Set 14 | impfondo
# Processing Record 30 of Set 14 | nara
# Processing Record 31 of Set 14 | joura
# Processing Record 32 of Set 14 | kahului
# Processing Record 33 of Set 14 | rumoi
# Processing Record 34 of Set 14 | fairbanks
# Processing Record 35 of Set 14 | nouadhibou
# Processing Record 36 of Set 14 | brokopondo
# Processing Record 37 of Set 14 | nisporeni
# Processing Record 38 of Set 14 | lompoc
# Processing Record 39 of Set 14 | tonj
# Processing Record 40 of Set 14 | ericeira
# Processing Record 41 of Set 14 | middletown
# Processing Record 42 of Set 14 | yian
# City not found. Skipping...
# Processing Record 43 of Set 14 | stephenville
# Processing Record 44 of Set 14 | zabol
# Processing Record 45 of Set 14 | khalabat
# Processing Record 46 of Set 14 | annonay
# Processing Record 47 of Set 14 | lahij
# Processing Record 48 of Set 14 | progreso
# Processing Record 49 of Set 14 | lillooet
# Processing Record 50 of Set 14 | laguna
# Processing Record 1 of Set 15 | parana
# Processing Record 2 of Set 15 | rozkishne
# Processing Record 3 of Set 15 | sibut
# Processing Record 4 of Set 15 | brae
# Processing Record 5 of Set 15 | deer lake
# Processing Record 6 of Set 15 | santo antonio do ica
# Processing Record 7 of Set 15 | lithgow
# Processing Record 8 of Set 15 | los llanos de aridane
# Processing Record 9 of Set 15 | sangmelima
# Processing Record 10 of Set 15 | bouna
# Processing Record 11 of Set 15 | ongandjera
# Processing Record 12 of Set 15 | catuday
# Processing Record 13 of Set 15 | kota belud
# Processing Record 14 of Set 15 | helong
# Processing Record 15 of Set 15 | miandrivazo
# Processing Record 16 of Set 15 | corinto
# Processing Record 17 of Set 15 | shizunai
# Processing Record 18 of Set 15 | tual
# Processing Record 19 of Set 15 | the pas
# Processing Record 20 of Set 15 | iralaya
# Processing Record 21 of Set 15 | narok
# Processing Record 22 of Set 15 | puerto el triunfo
# Processing Record 23 of Set 15 | semnan
# Processing Record 24 of Set 15 | labe
# Processing Record 25 of Set 15 | sao domingos
# Processing Record 26 of Set 15 | whangamata
# Processing Record 27 of Set 15 | fort nelson
# Processing Record 28 of Set 15 | ust-barguzin
# Processing Record 29 of Set 15 | cam ranh
# Processing Record 30 of Set 15 | puerto del rosario
# Processing Record 31 of Set 15 | kapuskasing
# Processing Record 32 of Set 15 | kemi
# Processing Record 33 of Set 15 | daye
# Processing Record 34 of Set 15 | balaguer
# Processing Record 35 of Set 15 | hay river
# Processing Record 36 of Set 15 | bayir
# Processing Record 37 of Set 15 | beisfjord
# Processing Record 38 of Set 15 | urazovka
# Processing Record 39 of Set 15 | angra
# City not found. Skipping...
# Processing Record 40 of Set 15 | omsukchan
# Processing Record 41 of Set 15 | pangai
# Processing Record 42 of Set 15 | savannah bight
# Processing Record 43 of Set 15 | arlit
# Processing Record 44 of Set 15 | abalak
# Processing Record 45 of Set 15 | yining
# Processing Record 46 of Set 15 | xining
# Processing Record 47 of Set 15 | acuitzio
# Processing Record 48 of Set 15 | katherine
# Processing Record 49 of Set 15 | grahamstown
# Processing Record 50 of Set 15 | taltal
# Processing Record 1 of Set 16 | skalistyy
# City not found. Skipping...
# Processing Record 2 of Set 16 | leh
# Processing Record 3 of Set 16 | siocon
# Processing Record 4 of Set 16 | meulaboh
# Processing Record 5 of Set 16 | batagay
# Processing Record 6 of Set 16 | jalingo
# Processing Record 7 of Set 16 | qingyuan
# Processing Record 8 of Set 16 | tunceli
# Processing Record 9 of Set 16 | menzelinsk
# Processing Record 10 of Set 16 | werda
# Processing Record 11 of Set 16 | fare
# Processing Record 12 of Set 16 | palmas
# Processing Record 13 of Set 16 | ternate
# Processing Record 14 of Set 16 | santiago
# Processing Record 15 of Set 16 | weligama
# Processing Record 16 of Set 16 | osoyoos
# Processing Record 17 of Set 16 | northam
# Processing Record 18 of Set 16 | mendahara
# City not found. Skipping...
# Processing Record 19 of Set 16 | fort payne
# Processing Record 20 of Set 16 | iquique
# Processing Record 21 of Set 16 | plettenberg bay
# Processing Record 22 of Set 16 | port hardy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Yerbogachen  61.2767  108.0108    -44.25        78          47
# 1   Bronnoysund  65.4625   12.1997     30.20        69          75
# 2       Rikitea -23.1203 -134.9692     80.11        67          88
# 3   New Norfolk -42.7826  147.0587     66.99        87          54
# 4  Kudahuvadhoo   2.6708   72.8944     81.07        78          67
# 5     Esperance -33.8667  121.9000     55.40        88           1
# 6         Airai  -8.9266  125.4092     61.68       100         100
# 7      Tasiilaq  65.6145  -37.6368     15.80        86          90
# 8     Quelimane -17.8786   36.8883     82.40        89          75
# 9        Dikson  73.5069   80.5464    -31.92        85         100
#
#    Wind Speed Country Current Description
# 0        5.50      RU    scattered clouds
# 1       12.66      NO          light snow
# 2        7.54      PF     overcast clouds
# 3        1.01      AU       broken clouds
# 4       15.57      MV       broken clouds
# 5        5.75      AU           clear sky
# 6        4.12      TL          light rain
# 7       23.02      GL     overcast clouds
# 8        5.75      MZ       broken clouds
# 9        6.42      RU     overcast clouds

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Yerbogachen      RU  61.2767  108.0108    -44.25        78          47
# 1   Bronnoysund      NO  65.4625   12.1997     30.20        69          75
# 2       Rikitea      PF -23.1203 -134.9692     80.11        67          88
# 3   New Norfolk      AU -42.7826  147.0587     66.99        87          54
# 4  Kudahuvadhoo      MV   2.6708   72.8944     81.07        78          67
# 5     Esperance      AU -33.8667  121.9000     55.40        88           1
# 6         Airai      TL  -8.9266  125.4092     61.68       100         100
# 7      Tasiilaq      GL  65.6145  -37.6368     15.80        86          90
# 8     Quelimane      MZ -17.8786   36.8883     82.40        89          75
# 9        Dikson      RU  73.5069   80.5464    -31.92        85         100
#
#    Wind Speed Current Description
# 0        5.50    scattered clouds
# 1       12.66          light snow
# 2        7.54     overcast clouds
# 3        1.01       broken clouds
# 4       15.57       broken clouds
# 5        5.75           clear sky
# 6        4.12          light rain
# 7       23.02     overcast clouds
# 8        5.75       broken clouds
# 9        6.42     overcast clouds

# %%
output_data_file = 'WeatherPy_Database.csv'

city_data_df.to_csv(output_data_file, index_label='City_ID')
