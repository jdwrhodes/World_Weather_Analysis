# %%
# Dependencies
import pandas as pd
import requests
import numpy as np
import matplotlib.pyplot as plt

# %%
rain_df = pd.read_csv('Assessment_Resources/avg_rain_state.csv')
rain_df
# Out:
#              State  Inches  Milli­metres  Rank
# 0          Alabama    58.3          1480     4
# 1           Alaska    22.5           572    39
# 2          Arizona    13.6           345    47
# 3         Arkansas    50.6          1284     8
# 4       California    22.2           563    40
# 5         Colorado    15.9           405    44
# 6      Connecticut    50.3          1279     9
# 7         Delaware    45.7          1160    16
# 8          Florida    54.5          1385     5
# 9          Georgia    50.7          1287     7
# 10          Hawaii    63.7          1618     1
# 11           Idaho    18.9           481    42
# 12        Illinois    39.2           996    27
# 13         Indiana    41.7          1060    26
# 14            Iowa    34.0           864    31
# 15          Kansas    28.9           733    35
# 16        Kentucky    48.9          1242    12
# 17       Louisiana    60.1          1528     2
# 18           Maine    42.2          1072    23
# ...

# %%
rain_df.sort_values(['Rank'], ascending=False).tail()
# Out:
#           State  Inches  Milli­metres  Rank
# 8       Florida    54.5          1385     5
# 0       Alabama    58.3          1480     4
# 23  Mississippi    59.0          1499     3
# 17    Louisiana    60.1          1528     2
# 10       Hawaii    63.7          1618     1

# %%
url = "https://api.spacexdata.com/v2/launchpads"
response = requests.get(url).json()

# %%
response
# Out:
# [{'padid': 5,
#   'id': 'vafb_slc_3w',
#   'name': 'VAFB SLC 3W',
#   'full_name': 'Vandenberg Air Force Base Space Launch Complex 3W',
#   'status': 'retired',
#   'location': {'name': 'Vandenberg Air Force Base',
#    'region': 'California',
#    'latitude': 34.6440904,
#    'longitude': -120.5931438},
#   'vehicles_launched': ['Falcon 1'],
#   'attempted_launches': 0,
#   'successful_launches': 0,
#   'wikipedia': 'https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_3',
#   'details': 'SpaceX original west coast launch pad for Falcon 1. Performed a static fire but was never used for a launch and abandoned due to scheduling conflicts.'},
#  {'padid': 2,
#   'id': 'ccafs_slc_40',
#   'name': 'CCAFS SLC 40',
#   'full_name': 'Cape Canaveral Air Force Station Space Launch Complex 40',
#   'status': 'active',
#   'location': {'name': 'Cape Canaveral',
#    'region': 'Florida',
#    'latitude': 28.5618571,
#    'longitude': -80.577366},
# ...

# %%
for name in response:
    print(type(name))
# Out:
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>

# %%
donors_df = pd.read_csv('Assessment_Resources/donors2008.csv')

# %%
donors_df.head()
# Out:
#   LastName FirstName          Employer      City State    Zip  Amount  FIELD8
# 0    Aaron    Eugene  State Department    Dulles    VA  20189   500.0     NaN
# 1    Abadi   Barbara       Abadi & Co.  New York    NY  10021   200.0     NaN
# 2  Adamany   Anthony           Retired  Rockford    IL  61103   500.0     NaN
# 3    Adams  Lorraine              Self  New York    NY  10026   200.0     NaN
# 4    Adams    Marion              None    Exeter    NH  03833   100.0     NaN

# %%
avg_donor = donors_df.groupby(['State']).mean()['Amount']

# %%
avg_donor
# Out:
# State
# AE     100.000000
# AK     175.000000
# AL     212.500000
# AP     200.000000
# AR     350.000000
# AZ     206.000000
# CA     685.234973
# CO     851.250000
# CT     825.714286
# DC     647.115385
# DE     190.000000
# FL     709.358974
# GA     842.307692
# HI     195.454545
# IA     600.000000
# ID     341.666667
# IL    1114.519231
# IN     225.000000
# KS     283.333333
# KY     735.000000
# LA     158.333333
# MA     750.714286
# MD     819.823529
# ME     211.111111
# MI     241.666667
# MN     697.000000
# MO     463.888889
# MS    1208.333333
# MT     200.000000
# NC     440.625000
# NE     183.333333
# NH     368.750000
# NJ     276.111111
# NM     298.913043
# NV     393.333333
# NY     910.829146
# OH     501.562500
# OK     200.000000
# OR     321.052632
# PA     896.755556
# QC     250.000000
# RI     700.000000
# SC     287.500000
# TN     257.142857
# TX     485.193182
# UT     200.000000
# VA     701.093465
# VI     225.000000
# VT     350.000000
# ...

# %%
try:
    print("Infinity looks like + " + str(10 / 0) + ".")
except :
    try:
        print("I think her name was + " + name + "?")
    except :
        try:
            print("Your name is a nonsense number. Look: " + int("Gabriel"))
        except :
            print("I made it through the gauntlet. The message survived!")
# Out:
# I made it through the gauntlet. The message survived!

# %%
df = pd.read_csv('Assessment_Resources/avg_rain_state.csv')

# %%
df
# Out:
#              State  Inches  Milli­metres  Rank
# 0          Alabama    58.3          1480     4
# 1           Alaska    22.5           572    39
# 2          Arizona    13.6           345    47
# 3         Arkansas    50.6          1284     8
# 4       California    22.2           563    40
# 5         Colorado    15.9           405    44
# 6      Connecticut    50.3          1279     9
# 7         Delaware    45.7          1160    16
# 8          Florida    54.5          1385     5
# 9          Georgia    50.7          1287     7
# 10          Hawaii    63.7          1618     1
# 11           Idaho    18.9           481    42
# 12        Illinois    39.2           996    27
# 13         Indiana    41.7          1060    26
# 14            Iowa    34.0           864    31
# 15          Kansas    28.9           733    35
# 16        Kentucky    48.9          1242    12
# 17       Louisiana    60.1          1528     2
# 18           Maine    42.2          1072    23
# ...

# %%
tick_locations = [value for value in np.arange(len(df))]
plt.figure(figsize=(20,3))
plt.bar(df['State'],df['Inches'])
plt.xticks(tick_locations, df['State'], rotation='vertical')
plt.title("Rain in Inches by State")
plt.xlabel("State")
plt.ylabel("Rain (inches)")
plt.show()

# %%
import json
import os

filepath = os.path.join("Assessment_Resources/youtube_response.json")
with open(filepath) as jsonfile:
    video_json = json.load(jsonfile)

# %%
video_json['data']['items'][0]['thumbnail']['default']
# Out:
# 'http://i.ytimg.com/vi/hYB0mn5zh2c/default.jpg'

# %%
df.columns
# Out:
# Index(['State', 'Inches', 'Milli­metres', 'Rank'], dtype='object')

# %%
df.head(10)
# Out:
#          State  Inches  Milli­metres  Rank
# 0      Alabama    58.3          1480     4
# 1       Alaska    22.5           572    39
# 2      Arizona    13.6           345    47
# 3     Arkansas    50.6          1284     8
# 4   California    22.2           563    40
# 5     Colorado    15.9           405    44
# 6  Connecticut    50.3          1279     9
# 7     Delaware    45.7          1160    16
# 8      Florida    54.5          1385     5
# 9      Georgia    50.7          1287     7

# %%
df.to_csv('data_file.csv')

# %%
import os
import csv
cereal_csv = os.path.join("Assessment_Resources/cereal.csv")

with open(cereal_csv, newline="") as csvfile:
    csvreader = csv.reader(csvfile, delimiter=",")

    csv_header = next(csvfile)

    for row in csvreader:
        if float(row[7]) >= 5:
            print(row[0])
# Out:
# 100% Bran
# All-Bran
# All-Bran with Extra Fiber
# Bran Flakes
# Fruit & Fibre Dates; Walnuts; and Oats
# Fruitful Bran
# Post Nat. Raisin Bran
# Raisin Bran

# %%
pies = ["Apple", "Pumpkin", "Chocolate Creme", "Cherry", "Apple Crumb", "Pecan", "Lemon Meringue", "Blueberry", "Key Lime", "Peach"]
pie_votes = [47,37,32,27,25,24,24,21,18,16]
colors = ["yellow","green","lightblue","orange","red","purple","pink","yellowgreen","lightskyblue","lightcoral"]
offset = [0,0,0,0.2,0,0,0,0,0,0]

plt.pie(pie_votes, explode = offset, labels = pies, colors=colors, autopct='%.1f%%')
plt.show()

# %%
df['Inches'].mode()
# Out:
# 0    28.9
# 1    42.2
# 2    50.3
# dtype: float64

# %%
test_grades = {
    'Class': ['Oct', 'Oct', 'Jan', 'Jan', 'Oct', 'Jan'], 
    'Name': ["Cyndy", "Logan", "Laci", "Elmer", "Crystle", "Emmie"], 
    'Test Score': [90, 59, 72, 88, 98, 60]}

# %%
tg_df = pd.DataFrame(test_grades)

# %%
tg_df
# Out:
#   Class     Name  Test Score
# 0   Oct    Cyndy          90
# 1   Oct    Logan          59
# 2   Jan     Laci          72
# 3   Jan    Elmer          88
# 4   Oct  Crystle          98
# 5   Jan    Emmie          60

# %%
bins = [0, 59, 69, 79, 89, 100]

# %%
letter_grades = ['F', 'D', 'C', 'B', 'A']

# %%
tg_df['Letter Grade'] = pd.cut(tg_df['Test Score'], bins, labels=letter_grades)

# %%
tg_df
# Out:
#   Class     Name  Test Score Letter Grade
# 0   Oct    Cyndy          90            A
# 1   Oct    Logan          59            F
# 2   Jan     Laci          72            C
# 3   Jan    Elmer          88            B
# 4   Oct  Crystle          98            A
# 5   Jan    Emmie          60            D

# %%
students = ("Frank", "Mary", "Jasmine", "Ivana", "Ahmed")
students.append("Serena")
print(students)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-72be960c98fd> in <module>
#       1 students = ("Frank", "Mary", "Jasmine", "Ivana", "Ahmed")
# ----> 2 students.append("Serena")
#       3 print(students)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
classroom_1 = ['jim', 'sandy']
classroom_2 = ['josh', 'alisha']
classroom_3 = ['Dan', 'Donna']

# %%
name = 'Dan'

# %%
if name in classroom_1:
    print(f'{name} is in the classroom_1')
elif name in classroom_2:
    print(f'{name} is in the classroom_2')
else:
    print(f'{name} is in the classroom_3')
# Out:
# Dan is in the classroom_3
